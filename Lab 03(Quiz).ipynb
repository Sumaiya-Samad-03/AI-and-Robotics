# %%
class BankAcc:
    def __init__(self, name, acc_no, balance, amount):
        self.name = name
        self.__balance = balance
        self.acc_no = acc_no
        self.amount = int(amount)
    def Show_Bankdetails(self):
        print("Your balance is ", self.__balance)
    def deposit(self, amount):
        self.__balance += amount
        print("Amount deposited successfully.")
obj = BankAcc(input("Enter your name "), 123456789, 10000, input("How much you want to deposit: "))
#print(obj.name)
#print(obj.acc_no)
#print(obj.amount)
obj.deposit(obj.amount)
password = input("Enter password to access balance: ")
if password == "1234" and obj.name == "Sumaiya":
        print("Access granted.")
        obj.Show_Bankdetails()
else:
  print("Access denied.")
try:
    pass
except AttributeError:
    print("You can't access balance of any person.")
# Out:
# Enter your name Sumaiya
# How much you want to deposit: 3000
# Amount deposited successfully.
# Enter password to access balance: 1234
# Access granted.
# Your balance is  13000

# %% [markdown]
# #Polymorphism
# functions inside of class are called methods

# %%
class Truck:
  def horn(self):
    print("PAAAA....  :)")
class car:
  def horn(self):
    print("Peeee...  :)")
tr = Truck()
ca = car()
tr.horn()
ca.horn()
# Out:
# PAAAA....  :)
# Peeee...  :)

# %%
print(input("Enter your name: "))
print(input("Enter your password: "))
class login:
  if obj.name == input("Enter your name: ") and obj.password == input("Enter your password: "):
    print("Access granted.")
    def __init__(self, name, password):
        self.name = name
        self.password = password

# %% [markdown]
# ###Inheritance
