# %% [markdown]
# Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Lists
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]
names = ['size', 'price']
df = pd.DataFrame(list(zip(x, y)), columns = names)
print(df)
# Out:
#    size  price
# 0     1      2
# 1     2      4
# 2     3      6
# 3     4      8

# %%
#Lists
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]


for i in range(4):
    result = 0
    for j in range(4):
        result += x[j] * y[i]
    print(result)

x_np = np.array(x)
y_np = np.array(y)
z = x_np * y_np
print(z)
#matrics = np.array(z)
#print(matrics)
# Out:
# 20
# 40
# 60
# 80
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_323/2406766637.py in <cell line: 0>()
#      10     print(result)
#      11
# ---> 12 x_np = np.array(x)
#      13 y_np = np.array(y)
#      14 z = x_np * y_np
#
# NameError: name 'np' is not defined

# %%
data = {
'size' : [10, 9, 8, 7, 6],
'price' : [2, 4, 6, 8, 10]
}
df = pd.DataFrame(data)
plt.figure = plt.figure(figsize = (10, 5))
plt.scatter(df['size'], df['price'])

# %%
print(df)
# Out:
#    size  price
# 0    10      2
# 1     9      4
# 2     8      6
# 3     7      8
# 4     6     10

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import importlib

importlib.reload(plt)
sns.scatterplot(df, x = 'size', y = 'price')
# Out:
# <Axes: xlabel='size', ylabel='price'>

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
def regline(w, x, b):
  y = 0
  y = x*w + b
  return y
w = 0
b = 0
x = df['size'].values
yPred = regline(w, x, b)
print("Predicted values of y are: ")
print(yPred)
sns.regplot(x = 'size', y = yPred, data = df, ci = None, line_kws = {'color': 'green'})
# Out:
# Predicted values of y are:
# [0 0 0 0 0]
# <Axes: xlabel='size'>

# %%
def costFunction(n,y,yPred):
 cost=0
 error=0
 sq=0

 error=yPred-y
 print("A price", y)
 print("P price", yPred)
 print("Error ",error)

 sq=error **2 #square
 print("square ",error, sq)


 print("s q type", type(sq))
 cost=np.sum(sq)

 print("Sum of squares is  ",cost)
 cost=cost/(2*n)
 return cost

cost=costFunction(n,y,yPred)
print("Cost is ",cost)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2536/2717498052.py in <cell line: 0>()
#      20  return cost
#      21
# ---> 22 cost=costFunction(n,y,yPred)
#      23 print("Cost is ",cost)
#
# NameError: name 'n' is not defined

# %%
def costfunc(n, y, yPred):

# %%
# !dir
# Out:
# drive  sample_data

# %%
# !cd drive

# %%
# !dir
# Out:
# drive  sample_data

# %%
# !cd drive

# %%
# !pwd
# Out:
# /content

# %%
# !cd /content/drive/MyDrive

# %%
pwd
# Out:
# '/content/drive/MyDrive'

# %%
# !dir
# Out:
# 55ecfc_4584f1e88b7b4b02b57ff4cecfe5efb2_copy.pdf
# AI\ and\ Robotics
# AI\ labs
# Background\ Wallpapers
# Bookmarks.gdoc
# Books
# courses
# FYP
# FYP.gdoc
# Host–Pathogen\ Interactions.gslides
# MPL\ Assignment.gdoc
# MPL\ Lab-03.gdoc
# Mycobacterium\ tuberculosis.gslides
# Python
# Python\ Django.gdoc
# Sumaiya\ Samad\ CV.pdf
# Untitled\ document.gdoc

# %%
# !ls
# Out:
#  55ecfc_4584f1e88b7b4b02b57ff4cecfe5efb2_copy.pdf
# 'AI and Robotics'
# 'AI labs'
# 'Background Wallpapers'
#  Bookmarks.gdoc
#  Books
#  courses
#  FYP
#  FYP.gdoc
# 'Host–Pathogen Interactions.gslides'
# 'MPL Assignment.gdoc'
# 'MPL Lab-03.gdoc'
# 'Mycobacterium tuberculosis.gslides'
#  Python
# 'Python Django.gdoc'
# 'Sumaiya Samad CV.pdf'
# 'Untitled document.gdoc'
